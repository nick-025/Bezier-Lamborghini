# %% [markdown]
# # Avaliação somativa 17/09/2020
# - #### Pontifícia Universidade Católica do Paraná;
# - #### Escola Politécnica;
# - #### Ciência da Computação;
# - #### Construção de Software Gráfico 3D: Matemática;
# - #### **Manoel Felipe de Almeida Bina e Nicholas Davi da Cruz.**
# <br>
# Neste notebook, nós realizamos o início do nosso TDE sobre plotagem gráfica do perfil de um carro vendido comercialmente. Nós escolhemos o mesmo modelo que utilizamos no TDE, a Lamborghini de edição limitada Sián FKP 37.

# %%
import math

import matplotlib.patches as patches
import matplotlib.path as path
import matplotlib.pyplot as plt
import numpy as np

# %%
reta = lambda P1, P2, lw = 1, cor = "black", ls = "-", a = 1: plt.plot([P1[0] + u*(P2[0]-P1[0]) for u in (0, 1)], [P1[1] + u*(P2[1]-P1[1]) for u in (0, 1)], color = cor, lw = lw, linestyle = ls, alpha = a)

# %%
Path = path.Path

fig, ax = plt.subplots()

reta((32.5, 162.5), (22.5, 162.5)) # Pequena reta horizontal do escapamento

exhaust_M = patches.PathPatch( # Primeira metade do ESCAPAMENTO até o ponto máximo da curva
    Path([(22.5, 162.5), (12.4, 145.5), (17.3, 133.6)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

exhaust_f = patches.PathPatch( # Segunda metade do ESCAPAMENTO até o ponto final
    Path([(17.3, 133.6), (24.7, 124.199), (38.4, 119.1), (42.9, 118.0)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: ESCAPAMENTO




back_bumper = patches.PathPatch( # Primeira metade da curva do PARACHOQUE TRASEIRO até o ponto máximo da curva
    Path([(42.9, 118.0), (50.0, 98.0), (49.6, 91.9), (64.6, 86.6), (64.6, 86.6), (72.6, 83.6), (93.5, 74.6), (135.5, 64.5),
         (132.3, 73.69), (43.0, 100.69), (68.7, 85.0), (29.7, 170.3)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: PARACHOQUES




back_fender_start = patches.PathPatch( # Curvinha do comecinho do PARALAMAS TRASEIRO perto do PARACHOQUE e da RODA
    Path([(135.5, 64.5), (128.0, 82.6), (128.9, 95.6), (129.9, 103.0), (291.5, 149.9), (332.0, 96.199), (335.9, 102.69), (317.3, 64.69),
         (317.3, 64.69), (315.5, 61.89), (315.0, 58.6), (308.7, 58.19)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

reta((124.4, 107.0), (129.9, 103.0)) # Pequena reta ascendente da esquerda para a direita do começo do PARALAMAS
reta((123.5, 84.65), (123.5, 118.3)) # Reta vertical perto do PARALAMAS indo para o corpo do carro

back_fender_middle = patches.PathPatch( # Primeira metade da curva do PARALAMAS TRASEIRO perto do PARACHOQUE e da RODA
    Path([(124.3, 118.3), (137.3, 185.1), (210.4, 190.5)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

back_fender_middle_f = patches.PathPatch( # Segunda metade da curva do PARALAMAS TRASEIRO perto do ponto máximo ao meio
    Path([(210.4, 190.5), (261.8, 188.5), (284.5, 158.8), (291.2, 150.0)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

back_fender_f = patches.PathPatch( 
    Path([(291.2, 150.0), (299.0, 139.1), (306.0, 128.0), (317.3, 103.5)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

last_curve_back_fender = patches.PathPatch( # Fim do PARALAMAS TRASEIRO 
    Path([(317.3, 103.5), (316.5, 93.5), (313.2, 64.0), (305.5, 51.19)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

reta((305.0, 51.19), (305.0, 41.8)) # Reta vertical descendente do PARALAMAS para a BASE do carro ATÉ AQUI: TRASEIRA

front_fender_begining = patches.PathPatch( # Começo do PARALAMAS dianteiro da direita para a esquerda: COMEÇO DO POLÍGONO PERTO DA RODA
    Path([(795.0, 68.8), (768.5, 69.5),(753.0, 88.0)],
         [Path.MOVETO, Path.LINETO, Path.LINETO]),
    fc="none", transform=ax.transData, color="black", lw = 1)

left_part_polygon = patches.PathPatch(
    Path([(753.3, 92.3), (754.3, 100.0), (771.0, 121.3), (785.7, 140.0), (798.3, 142.7), (787.5, 112.8), (787.8, 86.8), (795.0, 68.8)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.LINETO]),
    fc="none", transform=ax.transData, color="black", lw = 1)

front_fender_semi_circle = patches.PathPatch(
    Path([(1076.0, 117.0), (966.7, 200.0), (893.2, 229.2), (761.8, 185.8), (806.2, 152.8), (348.9, 189.0), (264.0, 195.1), (277.7, 196.3), (255.7, 179.8)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.LINETO, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

friso = patches.PathPatch(
    Path([(811.2, 166.8), (883.0, 214.8), (945.2, 168.2)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.3)

friso3 = patches.PathPatch(
    Path([(149.3, 179.0), (212.0, 214.8), (279.3, 176.7)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.3)

# Até aqui: PARALAMAS

reta((305.5, 41.8), (795.5, 41.19)) # Reta da BASE do carro
reta((795.5, 41.19), (795.2, 57.0)) # Reta vertical ascendente da BASE para o ZIG-ZAG PORTA
reta((328.0, 95.4), (505.5, 78.5), 1, "gray", "-", 0.4)
reta((407.3, 143.6), (505.5, 78.5), 1, "gray", "-", 0.4)
reta((732.3, 60), (714.6, 43.6), 1)

barra_lateral = patches.PathPatch(
    Path([(317.3, 64.8), (435.7, 56.5), (369.2, 67.69), (445.0, 43.0), (413.2, 53.89), (592.5, 41.6), (714.6, 43.6)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: BASE




zigzag = patches.PathPatch( # Começo do ZIG-ZAG PORTA da direita para a esquerda subindo
    Path([(795.2, 57.0), (528.0, 74.5), (519.5, 80.5), (350.0, 188.5), (364.4, 198.5), (399.2, 208.0)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

zigzag1 = patches.PathPatch( # Meio do ZIG-ZAG PORTA da direita para a esquerda subindo
    Path([(519.5, 80.5), (477.5, 100.5), (362.0, 178.5), (350.0, 188.5), (399.2, 208.0), (314.2, 235.8), (244.0, 236.7), (183.0, 234.3)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

zigzag_ext1 = patches.PathPatch( # Meio do ZIG-ZAG PORTA da direita para a esquerda subindo
    Path([(183.0, 234.3), (247.5, 238.1), (341.5, 235.0), (417.5, 207.0), (417.5, 207.0), (390.3, 201.0), (373.0, 187.5), 
          (373.0, 187.5), (474.5, 111.0), (548.0, 79.0),
          (548.0, 79.0), (555.3, 76.0), (786.6, 57.5), (794.9, 56.89),
          (483.3, 232.3), (470.0, 226.0), (461.0, 207.7), (451.7, 205.0), (451.7, 205.0), (449.7, 196.0), (483.3, 112.0), (504.3, 101.3)], 
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

friso2 = patches.PathPatch( # Meio do ZIG-ZAG PORTA da direita para a esquerda subindo
    Path([(483.3, 232.3), (470.0, 226.0), (461.0, 207.7), (451.7, 205.0), (451.7, 205.0), (449.7, 196.0), (483.3, 112.0), (504.3, 101.3)], 
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.3)

# Até aqui: ZIG-ZAG PORTA




fin_ascending_start = patches.PathPatch( # Começo da BARBATANA da direita para a esquerda subindo
    Path([(183.0, 234.3), (143.5, 254.4), (162.9, 249.8), (103.2, 252.0)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

fin_top_descending = patches.PathPatch( # Topo da BARBATANA da direita para a esquerda descendo
    Path([(103.2, 252.0), (70.5, 251.9), (86.1, 256.5), (50.4, 230.0)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

reta((183.0, 234.3), (49.4, 226.8)) # Pequena linha que liga o fim da BARBATANA ao começo
reta((49.4, 226.8), (50.4, 230.0)) # Linha de baixo da BARBATANA da esquerda para a direita subindo um pouquinho e fechando a figura

fin_hole = patches.PathPatch(
    Path([(90.2, 246.0), (99.9, 246.0), 
          (99.9, 246.0), (101.7, 246.0), (89.8, 230.2), 
          (89.8, 230.2), (89.1, 229.8), (76.9, 230.0), 
          (76.9, 230.0), (76.3, 230.0), (76.4, 236.1), (76.7, 236.7), 
          (76.7, 236.7), (77.3, 237.7), (90.2, 246.0)],
         [Path.MOVETO, Path.LINETO,  
          Path.MOVETO, Path.CURVE3, Path.CURVE3, 
          Path.MOVETO, Path.CURVE3, Path.CURVE3, 
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE3, Path.CURVE3],
         ),
    fc="none", transform=ax.transData, color="black", lw = 1)

back_fin = patches.PathPatch(
    Path([(160.1, 248.1), (172.9, 258.1), (175.7, 260.8), 
          (175.7, 260.8), (178.8, 262.5), (176.0, 264.2), (232.5, 261.8)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, 
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

back_fin_hole = patches.PathPatch(
    Path([(185.9, 253.0), (191.2, 259.0), (192.0, 259.0), 
          (192.0, 259.0), (199.0, 259.2), (199.1, 259.0), 
          (199.1, 259.0), (199.3, 258.9), (199.0, 254.0)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: BARBATANAS




reta((50.4, 230.0), (37.0, 230.0)) # Reta de saindo da BARBATANA para a TRASEIRA do carro da direita para a esquerda

spike_descending_line_left = patches.PathPatch( # Pequena curva que sai da BARBATANA e desce para a extremidade do carro da direita para a esquerda
    Path([(37.0, 230.0), (28.5, 223.3), (24.0, 215.7)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

spike_descending_line_right = patches.PathPatch( # Pequena curva que desce da outra curva anterior em direção à frente do carro da esquerda para a direita
    Path([(24.0, 215.7), (23.9, 214.2), (28.1, 206.1)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

reta((28.1, 206.0), (28.1, 170.7)) # Reta vertical que sai do spike na ponta e desce à reta do ESCAPAMENTO

backwards = patches.PathPatch(
    Path([(65.8, 196.6), (115.5, 213.7), (164, 225.3), (182.5, 235.1), (65.8, 196.6), (70.23, 184.3), (70.94, 169.5), (77.77, 160.1),
          (124, 119.17), (106.2, 130.8), (91.6, 144.2), (77.77, 160.1), (123.2, 84.24), (87.1, 91.6), (89.1, 91.5), (82.5, 106.7),
          (46.6, 199.1), (59, 163.5), (75.4, 121), (82.5, 106.7), (46.6, 199.1), (44.6, 223.5), (41.4, 224.4), (48.76, 227.47),
         ],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

lanternas = patches.PathPatch(
    Path([(45.4, 208.0), (37.1, 207.6), (36.0, 207.5),
          (36.0, 207.5), (33.8, 206.8), (34.5, 194.7), (35.7, 194.9),
          (35.7, 194.9), (39.3, 194.6), (40.2, 194.9), 
          (46.2, 205.9), (41.1, 206.0), (41.0, 205.7),
          (41.0, 205.7), (37.7, 196.9), (42.1, 190.6),
          (42.1, 190.6), (42.3, 190.3), (49.0, 190.4),
          (44.3, 190.4), (38.3, 184.0), (42.4, 175.4),
          (42.4, 175.4), (44.8, 174.3), (55.5, 173.3),
          (48.0, 174.1), (44.0, 175.5), (45.1, 190.4),],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: TRASEIRA




long_curve_back_center = patches.PathPatch( # Curva longa que vai de cima do ZIG-ZAG para o centro do carro da esquerda para a direita descendo
    Path([(177.2, 237.7), (273.5, 240.0), (292.0, 256.5), (595.0, 162.5)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

intermediate_descendant_curve = patches.PathPatch( # Curva pequena que desce da curva maior em direção à TRASEIRA do carro da direita para a esquerda
    Path([(595.0, 162.5), (536.5, 130.8), (499.2, 122.8), (490.6, 118.6)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

final_long_descendant_curve = patches.PathPatch( # Curva longa que desce da curva intermediária em direção à frente do carro da esquerda para a direita
    Path([(490.6, 118.6), (498.4, 112.9), (522.8, 97.19), (543.6, 86.5)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

bottom_tiny_curve = patches.PathPatch( # Curva longa que desce da curva intermediária em direção à frente do carro da esquerda para a direita
    Path([(543.6, 86.5), (547.2, 84.9), (548.1, 84.1), (554.8, 83.6)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

bottom_long_curve = patches.PathPatch( # Curva longa que desce da curva intermediária em direção à frente do carro da esquerda para a direita
    Path([(554.8, 83.6), (601.9, 79.1), (794.1, 65.1)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

reta((794.1, 65.1), (795.0, 68.8))

forked_line_bottom = patches.PathPatch( # Curvas bifurcadas longas vindas da parte traseira
    Path([(753.0, 88.0), (748.0, 90.0), (506.1, 115.1), (490.6, 118.6)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

forked_line_top = patches.PathPatch( # Curvas bifurcadas longas vindas da parte traseira
    Path([(753.3, 92.3), (728.3, 94.3), (490.6, 118.6)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

upper_forked_line_bottom = patches.PathPatch( # Curvas bifurcadas longas vindas da parte traseira
    Path([(785.7, 140.0), (753.0, 148.7), (685.7, 158.7), (595.3, 162.3)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

upper_forked_line_top = patches.PathPatch( # Curvas bifurcadas longas vindas da parte traseira
    Path([(595.3, 162.3), (685.7, 162.7), (798.3, 142.7)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: CURVAS LONGAS CENTRO




roof_quadratic = patches.PathPatch( # Curva longa que desce da curva intermediária em direção à frente do carro da esquerda para a direita
    Path([(159.0, 246.9), (412.0, 301.0), (552.0, 298.0),
          (552.0, 298.0), (678.5, 297.5), (861.0, 231.5)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

roof_cubic = patches.PathPatch( # Curva do TETO
    Path([(222.0, 240.5), (251.5, 245.5), (422.5, 281.5), (550.5, 278.5),
          (550.5, 278.5), (677.0, 278.0), (728.0, 261.5), (833.5, 210.5)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: TETO




window_part = patches.PathPatch(
    Path([(412.2, 270.5), (438.6, 256.5), (479.1, 234.8), (504.8, 224)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

window_part_bottom = patches.PathPatch(
    Path([(504.8, 224), (556.9, 208.5), (640.8, 203.3), (719.4, 195.8), (628, 271.5), (675.2, 265.4), (722.1, 256.5), (827.5, 210.15),
          (628, 271.5), (576.6, 276.9), (500.8, 281.1), (430.85, 261.05), (746.6, 192.9), (757.2, 186.9), (797.5, 158.8), (805.8, 150.7)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

reta((798.3, 142.7), (805.8, 150.7))
reta((746.6, 192.9), (738.7, 192.9))
reta((728.8, 239.7), (728.8, 248.7))
reta((728.8, 239.7), (728.8, 248.7))
reta((743.2, 197.5), (743.2, 194.2))

# Até aqui: JANELA




rearview = patches.PathPatch( # 
    Path([(713.73, 189.84), (721.1, 196.24), (726.6, 202.6), (729.7, 206.7), (705.95, 212.26), (701.4, 218.6), (700.2, 230.16), (703.2, 235.2),
          (703.2, 235.2), (727.1, 242.8), (753.66, 239.1), (764.8, 221.15), (764.8, 221.15), (762.9, 218.1), (760.6, 216.62), (757.08, 215.1),
          (729.7, 206.7), (721.7, 207.5), (715.27, 209.2), (705.95, 212.26), (757.08, 215.1), (754.3, 209.17), (744.6, 198.4), (738.1, 191.6),
          (738.1, 191.6), (731.6, 186.17), (724.9, 183.96), (717.55, 183.63), (717.1, 183.63), (714.63, 185.4), (713.73, 186.53), (713.73, 189.84),
          (716.36, 184.33), (723.05, 189.04), (732.73, 198.86), (739.67, 208.5), (715.57, 213.46), (722.2, 208.82), (730.95, 208.6), (739.67, 208.5),
          (705.95, 212.26), (717.8, 213.36), (730.1, 214.6), (736.76, 221.65), (703.2, 235.2), (717.5, 235.1), (733.7, 227.4), (736.76, 221.65),
          (705.5, 222.67), (705, 227.25), (716.8, 225.36), (736, 223.9), (705.5, 222.67), (707.2, 217.64), (718.8, 219.44), (736.04, 219.84)
         ],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, 
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, 
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, 
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, 
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          ]),
    fc="none", transform=ax.transData, color="black", lw = 1)

reta((737.5, 190.0), (751.3, 182.6), 1)
reta((751.3, 182.6), (716.7, 182.8), 1)

# Até aqui: RETROVISOR




hood_depth = patches.PathPatch( # Curva longa que desce da curva intermediária em direção à frente do carro da esquerda para a direita
    Path([(552.0, 298.0), (678.5, 297.5), (861.0, 231.5)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_depth_continuation = patches.PathPatch( # Continuação do CAPÔ
    Path([(861.0, 231.5), (880.7, 231.6), (890.0, 230.8), (894.2, 228.9)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_depth_continuation2 = patches.PathPatch( # Continuação do CAPÔ
    Path([(894.2, 228.9), (894.4, 229.1), (899.2, 227.0)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_depth_continuation3 = patches.PathPatch( # Continuação do CAPÔ
    Path([(899.2, 227.0), (930.4, 222.0), (986.3, 211.3), (1053.0, 176.0)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_depth_continuation4 = patches.PathPatch( # Continuação do CAPÔ
    Path([(1053.0, 176.0), (1072.8, 168.3), (1123.2, 147.8), (1160.6, 119.8)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_depth_back_mid = patches.PathPatch( # Continuação do CAPÔ
    Path([(1160.6, 119.8), (1162.0, 118.3), (1159.6, 117.5)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_front_mid = patches.PathPatch( # Continuação do CAPÔ
    Path([(1159.6, 117.5), (1155.7, 117.1), (1148.7, 116.69)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_front_detail = patches.PathPatch( # Continuação do CAPÔ
    Path([(1148.7, 116.69), (1146.7, 118.0), (1144.0, 119.199), (1113.1, 125.0)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.LINETO]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_front_detail1 = patches.PathPatch( # Continuação do CAPÔ
    Path([(1144.0, 119.199), (1133.6, 120.9), (1113.1, 125.0)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_above_front_fender = patches.PathPatch( # Continuação do CAPÔ
    Path([(1113.1, 125.0), (1073.5, 148.3), (957.7, 203.4), (883.0, 210.0)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_above_front_fender2 = patches.PathPatch( # Continuação do CAPÔ
    Path([(883.0, 210.0), (838.6, 213.8), (758.3, 187.3)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: CAPÔ




reta((758.3, 187.3), (750.5, 194.2)) # Pequena reta perto da janela e do retrovisor
reta((740.0, 238.5), (740.0, 245.5)) # Pequena reta perto da janela e do retrovisor

hood_part = patches.PathPatch( # Linha acima da continuação do CAPÔ que parece ser paralela, (segue o mesmo curso)
    Path([(750.5, 194.2), (772.0, 196.2), (851.5, 229.0), (976.5, 206.0), (976.5, 206.0), (988.5, 206.6), (918.2, 224.0), (899.2, 225.5)],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

hood_part1 = patches.PathPatch( # Bem emcima do CAPÔ, é uma intersecção entre CAPÔ e parabrisas
    Path([(899.2, 225.5), (889.2, 229.5), (886.8, 229.5), (867.5, 229.5), (887.8, 220.8), (888.3, 215.5), (860.8, 214.2),
          (664.7, 278.3), (750.0, 261.7), (860.8, 214.2), (664.7, 278.3), (674.3, 281.0), (682.7, 282.7),
          (1085.7, 112.3), (1108.2, 112.19), (1108.7, 113.8), (1108.7, 113.8), (1107.2, 115.5), (1084.0, 119.0), (1047.0, 139.0)
         ], [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.LINETO, Path.LINETO, Path.LINETO, Path.LINETO,
             Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE3, Path.CURVE3,
             Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.LINETO
         ]),
    fc="none", transform=ax.transData, color="black", lw = 1)

# Até aqui: ACIMA DO PARALAMAS ABAIXO DO CAPÔ




front_bumper = patches.PathPatch(
    Path([(969.6, 54.6), (1045.4, 52.1), (1099.8, 54.5), (1099.8, 54.5),(1112.0, 55.5), (1112.6, 54.5), (1117.4, 60.0),
          (1117.4, 60.0), (1122.1, 65.39), (1136.4, 90.9), (1141.5, 102.0), (1141.5, 102.0), (1146.0, 109.9), (1153.5, 102.0), (1154.4, 103.8), (1152.4, 114.8),
          (1153.5, 102.0), (1153.5, 97.6), (1143.9, 65.6), (1137.8, 55.3), # ↓↓↓ A partir daqui é o paralamas no sentido anti-horário
          (1137.8, 55.3), (1136.0, 39.5), (999.3, 41.3), (964.0, 40.6), (964.0, 40.6), (1004.3, 129.7), (932.2, 174.6), (910.7, 180.0),
          (910.7, 180.0), (857.7, 193.0), (830.7, 174.9), (806.2, 152.2), (1148.7, 82.5), (1158.2, 81.3), (1163.3, 75.5), (1157.5, 70.19),
          (1163.2, 65.5), (1163.3, 65.5), (1162.8, 64.5), (1147.3, 56.69), (1137.8, 55.3)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.LINETO, Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.LINETO, Path.LINETO,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
    fc="none", transform=ax.transData, color="black", lw = 1)

reta((1050.0, 72.0), (1076.0, 117.0), 1)

reta((1050.0, 72.0), (974.9, 73.3), 1)

reta((1050.0, 72.0), (1061.5, 72.0), 1)

reta((1085.6, 112.4), (1061.5, 72.0), 1)

lights = patches.PathPatch(
    Path([(1042.5, 148.5), (1034.5, 155.5), (1117.5, 117.5), (1121.5, 115.0), (1121.5, 115.0), (1145.8, 114.69), (1121.5, 114.9),
          (1121.5, 114.9), (1146.7, 115.3), (1149.3, 114.5), (1150.9, 113.3), (1151.8, 113.8), (1150.2, 112.0), (1142.9, 112.0), (1123.2, 111.4),
          (1123.2, 111.4), (1094.0, 88.1), (1071.6, 76.4), (1071.6, 76.4), (1070.5, 76.6), (1070.5, 77.3), (1071.5, 78.19),
          (1071.5, 78.19), (1083.1, 89.0), (1113.6, 110.6), (1117.1, 113.19), (1117.1, 113.19), (1079.3, 132.9), (1049.9, 145.8), (1042.5, 148.5)
         ],
         [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE3, Path.CURVE3,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
          Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4, Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4
         ]),
    fc="none", transform=ax.transData, color="black", lw = 0.75)




########################################################################################################################################### CRAZY TESTS: WARNING

#######################################
#                                     #
#    MOSTRAR PARA O ORLANDO:          #
#    FUNÇÃO DE ROTATE E REPLICA!!!    #
#                                     #
#######################################


def rotate(origin, point, angle):    ##### Função retirada do StackOverflow
    """
    Rotate a point counterclockwise by a given angle around a given origin.

    The angle should be given in radians.
    """
    ox, oy = origin
    px, py = point

    qx = ox + math.cos(angle) * (px - ox) - math.sin(angle) * (py - oy)
    qy = oy + math.sin(angle) * (px - ox) + math.cos(angle) * (py - oy)
    return qx, qy
    
def replica(center_of_rotation, times, points, codes, linewidth = 1, c = "black"):
    l = []
    angle = 0
    counter = 1
    while angle <= 360:
        for i in points: 
            l.append(rotate(center_of_rotation, i, math.radians(angle)))
            counter += 1
            if len(l) == len(points):
                ax.add_patch(patches.PathPatch(Path(l, codes), fc="none", transform=ax.transData, color=c, lw = linewidth))
                angle += 360/times
                l = []
            if angle >= 360:
                return

##################################################################################################################################### WARNING: CRAZY TESTES ABOVE

raios = [
    # Y esquerdo do raio da roda
    (876.5, 164.0), (877.1, 165.3), (878.2, 164.5), (878.2, 163.8),
    (878.2, 163.8), (878.4, 162.5), (877.9, 123.19), (878.2, 115.1),
    (878.2, 115.1), (875.5, 110.5), (874.1, 115.0), 
    (874.1, 115.0), (874.1, 126.8), (873.0, 129.8), (871.9, 131.7), 
    (871.9, 131.7), (868.4, 135.1), (850.0, 151.2), (846.9, 155.4),
    (846.9, 155.4), (845.9, 157.3), (846.2, 159.3), (848.9, 157.5),
    (848.9, 157.5), (871.6, 134.7), (872.5, 136.3), (874.0, 136.2),
    (874.0, 136.2), (876.1, 135.9), (876.3, 158.8), (876.5, 164.0),
    # Y direito do raio da roda
    (883.7, 163.3), (885.0, 164.7), (886.0, 163.2),
    (886.0, 163.2), (885.2, 137.2), (888.4, 136.4),
    (888.4, 136.4), (891.5, 135.2), (911.4, 155.6),
    (911.4, 155.6), (914.8, 156.1), (913.6, 153.4),
    (913.6, 153.4), (907.1, 146.0), (892.2, 134.8), (889.3, 129.6),
    (889.3, 129.6), (888.0, 124.6), (888.6, 123.4), (886.9, 113.8),
    (886.9, 113.8), (884.8, 111.3), (883.7, 113.9),
    (883.7, 113.9), (883.7, 163.3)
]

l = [(i[0]-665, i[1]+2.35) for i in raios]

codes = [
    # Y esquerdo do raio da roda
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    Path.MOVETO, Path.CURVE3, Path.CURVE3,
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    # Y direito do raio da roda
    Path.MOVETO, Path.CURVE3, Path.CURVE3,
    Path.MOVETO, Path.CURVE3, Path.CURVE3,
    Path.MOVETO, Path.CURVE3, Path.CURVE3,
    Path.MOVETO, Path.CURVE3, Path.CURVE3,
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
    Path.MOVETO, Path.CURVE3, Path.CURVE3,
    Path.MOVETO, Path.LINETO
]


# Até aqui: FRENTE

reta((502.5, 226.0), (500.9, 273.5), 1)

reta((507.5, 224.0), (505.9, 273.5), 1)

back_wheel = patches.Ellipse((216.0, 101.0), 161, 161, color="black", lw = 1, fill = False)
back_wheel_tire = patches.Ellipse((216.0, 101.0), 148, 148, color="black", lw = 1, fill = False)
back_wheel_lines = patches.Ellipse((216.0, 101.0), 127.25, 127.25, color="black", lw = 1, fill = False)
back_wheel_middle = patches.Ellipse((216.0, 101.0), 24, 24, color="black", lw = 1, fill = False)
back_tiny_wheel = patches.Ellipse((216.0, 101.0), 38, 38, color="black", lw = 1, fill = False)

front_wheel = patches.Ellipse((880.0, 98.8), 156, 156, color="black", lw = 1, fill = False)
front_wheel_tire = patches.Ellipse((880.0, 98.8), 143, 143, color="black", lw = 1, fill = False)
front_wheel_lines = patches.Ellipse((880.0, 98.8), 126, 126, color="black", lw = 1, fill = False)
front_wheel_middle = patches.Ellipse((880.0, 98.8), 24, 24, color="black", lw = 1, fill = False)
front_tiny_wheel = patches.Ellipse((880.0, 98.8), 38, 38, color="black", lw = 1, fill = False)

# Porta do tanque de combustível
ax.add_patch(patches.Ellipse((400,239), 31, 23.1, color="black", lw = 1, fill = False))
ax.add_patch(patches.Ellipse((400,239), 20, 15.1, color="black", lw = 1, fill = False))
ax.add_patch(patches.PathPatch(
    Path([(391.1,241.2), (409.9, 241.1), # Linhazinha horizontal de um lado ao outro
    # Triangulinho da portinha de gasolina
    (404.9, 238.0), (409.2, 238.1), (404.9, 239.0), (408.0, 235.4),
    (390.75, 237.1), (398.1, 239.8), (405.8, 233.6)], # Curvinha debaixo do Y
    [Path.MOVETO, Path.LINETO, Path.MOVETO, Path.LINETO, Path.MOVETO, Path.LINETO,
     Path.MOVETO, Path.CURVE3, Path.CURVE3]), fc="none", transform=ax.transData, color="black", lw = 0.8))

# Até aqui: RODAS

reta((66.7, 195.5), (144.5, 190.2), 1, "gray", '-', 0.3)

ax.add_patch(patches.PathPatch(
        Path([(431.1, 288.9), (419.6, 283.1), (412.7, 270.7)], [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="black", lw = 1))

ax.add_patch(patches.PathPatch(
        Path([(278.0, 240.0), (299.0, 252.3), (411.5, 269.7)], [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="black", lw = 1))

# Linha cinza do corpo do carro que é mencionada no comentário abaixo
ax.add_patch(patches.PathPatch(
        Path([(234.0, 251.2), (253.8, 258.3), (411.5, 269.7)], [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="gray", lw = 1, alpha = 0.7))

# Uma das linhas do formato do carro, está na parte de trás, perto daquela linha cinza mais forte
ax.add_patch(patches.PathPatch(
        Path([(167.5, 243.2), (173.1, 245.3), (246.7, 245.7)], [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="black", lw = 1))

# Raiozinhos de aerodinâmica: parecem longas balas sendo atiradas
ax.add_patch(patches.PathPatch(
        Path([(99.6, 207.9), (65.7, 208.4), (63.8, 209.9), (63.8, 209.9), (65.6, 211.7), (109.8, 210.4), 
              (146.0, 220.9), (65.0, 223.4), (65.9, 220.9), (65.9, 220.9), (66.6, 218.9), (138.4, 218.9)], 
             [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE3, Path.CURVE3,
              Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="black", lw = 1))

# Linha que acompanha o fluxo do teto, vindo lá de trás e indo até o meio do teto
ax.add_patch(patches.PathPatch(
        Path([(212.8, 257.0), (264.4, 260.8), (266.5, 262.0), 
              (266.5, 262.0), (270.9, 262.3), (422.5, 292.5), (515.5, 297.5)], 
             [Path.MOVETO, Path.CURVE3, Path.CURVE3, 
              Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4]),
        fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.5))

# Linha que completa o parachoque dianteiro, linha que desce até perto do paralamas dianteiro
ax.add_patch(patches.PathPatch(
        Path([(1061.0, 71.1), (1073.6, 71.1),
              (1073.6, 71.1), (1082.5, 71.0), (1084.7, 75.69), (1090.5, 79.6),
              (1090.5, 79.6), (1123.3, 81.6), (1140.9, 101.8)], 
             [Path.MOVETO, Path.LINETO,
              Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
              Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="black", lw = 1))

# Luzinha branca em forma de retângulo atrás do paralamas traseiro bem pertinho da roda
ax.add_patch(patches.PathPatch(
        Path([(138.4, 156.0), (110.0, 166.0), (109.1, 171.8), (143.0, 161.5)], 
             [Path.MOVETO, Path.LINETO, Path.LINETO, Path.LINETO]),
        fc="none", transform=ax.transData, color="black", lw = 1))

# Linhazinhas dentro das lanternas traseiras
ax.add_patch(patches.PathPatch(
        Path([(38.0, 195.8), (38.0, 207.0), (44.0, 204.9), (44.0, 192.2)], 
             [Path.MOVETO, Path.LINETO, Path.MOVETO, Path.LINETO]),
        fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.35))

# Linhazinha que acompanha aquele spike, aquele espinhozinho de trás do carro
ax.add_patch(patches.PathPatch(
        Path([(25.4, 214.1), (36.3, 226.5), (36.6, 226.6), (36.6, 226.6), (36.7, 226.7), (48.6, 226.6)], 
             [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.5))

# Detalhezinhos do escapamento
ax.add_patch(patches.PathPatch(
        Path([(29.5, 162.3), (25.9, 153.4), (24.5, 143.5), (24.5, 143.5), (24.5, 139.9), (26.5, 126.6),
              (34.8, 159.5), (32.5, 159.5), (32.5, 159.5), (30.8, 159.1), (28.1, 148.1), (28.1, 148.1), (39.4, 148.1),
              (16.1, 143.7), (41.8, 143.8), (42.1, 142.0), (16.2, 142.1)], 
             [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.CURVE3, Path.CURVE3,
              Path.MOVETO, Path.LINETO, Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.MOVETO, Path.LINETO,
              Path.MOVETO, Path.LINETO, Path.MOVETO, Path.LINETO]),
        fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.7))

# Detalhezinhos do escapamento
ax.add_patch(patches.PathPatch(
        Path([(29.4, 169.2), (58.1, 164.2), (29.4, 169.2), (74.4, 124.1)], 
             [Path.MOVETO, Path.LINETO, Path.MOVETO, Path.LINETO]),
        fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.3))

# Linhazinha de contorno perto da portinha de colocar gasolina
ax.add_patch(patches.PathPatch(
        Path([(308.0, 236.5), (397.0, 237.8), (494.0, 199.5)], 
             [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.3))

# Linha que faz um quaaase triângulo perto do parachoques traseiro
ax.add_patch(patches.PathPatch(
        Path([(44.1, 136.0), (35.9, 136.0), (35.9, 136.0), (51.0, 96.6), (56.1, 91.9)], 
             [Path.MOVETO, Path.LINETO, Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.7))

# Linha que faz um quaaase triângulo perto do parachoques traseiro
ax.add_patch(patches.PathPatch(
        Path([(1075.8, 116.0), (970.2, 125.3), (1009.3, 121.5), (1000.2, 117.5), (971.8, 118.5)], 
             [Path.MOVETO, Path.LINETO, Path.MOVETO, Path.LINETO, Path.LINETO]),
        fc="none", transform=ax.transData, color="black", lw = 1, alpha = 0.7))

def cores_italia(lista, c, a = 1):
    ax.add_patch(patches.PathPatch(
        Path(lista, [Path.MOVETO, Path.CURVE3, Path.CURVE3]),
        fc="none", transform=ax.transData, color=c, lw = 1.75, alpha = a))

cores_italia([(311.8, 265.5), (325.1, 266.15), (340.2, 267.695)], "green")
cores_italia([(340.2, 267.695), (349.8, 270.9), (373.3, 270.1)], "gray", 0.2)
cores_italia([(373.3, 270.6), (382.1, 271.4), (401.3, 272.9)], "red")

reta((1136.4, 58.39), (1120.0, 58.5), 1, "gray", "-", 0.3)

[ax.add_patch(i) for i in [
    exhaust_M, exhaust_f, back_bumper, zigzag, zigzag1, roof_quadratic, roof_cubic, back_wheel, front_wheel, zigzag_ext1,
    lanternas, back_fender_middle_f, back_fender_start, back_fender_middle, back_fender_f, last_curve_back_fender,
    front_fender_semi_circle, front_fender_begining, left_part_polygon, fin_ascending_start, fin_top_descending,
    front_bumper, lights, back_wheel_middle, upper_forked_line_bottom, upper_forked_line_top, spike_descending_line_left,
    spike_descending_line_right, front_wheel_middle, long_curve_back_center, intermediate_descendant_curve,
    final_long_descendant_curve, backwards, friso, barra_lateral, back_fin, bottom_tiny_curve, bottom_long_curve,
    forked_line_bottom, forked_line_top, window_part, window_part_bottom, rearview, friso3, hood_depth,
    hood_depth_continuation, hood_depth_continuation2, hood_depth_continuation3, hood_depth_continuation4, friso2,
    hood_depth_back_mid, hood_front_mid, hood_front_detail, hood_above_front_fender, hood_above_front_fender2, hood_part,
    hood_part1, front_wheel_tire, back_wheel_tire, fin_hole, back_tiny_wheel, front_tiny_wheel, back_wheel_lines,
    front_wheel_lines, back_fin_hole
    ]
]

###### RAIOS DO CARRO: DIANTEIRA
# Estes dois primeiros são pra apagar os pedacinhos pretos da circunferência menor de dentro dos raios
replica((880.0, 98.8), 5, ((874.2, 116.69), (875.7, 118.3), (878, 117.9)), (Path.MOVETO, Path.CURVE3, Path.CURVE3), 3, "white")
replica((880.0, 98.8), 5, ((884.2, 116.69), (884.7, 117.85), (888, 116.9)), (Path.MOVETO, Path.CURVE3, Path.CURVE3), 3, "white")
# Y QUE VAI SER REPETIDO AO LONGO DE 5 VEZES
replica((880.0, 98.8), 5, raios, codes, 0.6)

###### RAIOS DO CARRO: TRASEIRA 
########################################################## em caso de dar errado: primeiros ticks de apagar (874.2, 116.69), (875.7, 118.3), (878, 117.9)
########################################################## em caso de dar errado: primeiros ticks de apagar (884.2, 116.69), (884.7, 117.85), (888, 116.9)
# Estes dois primeiros são pra apagar os pedacinhos pretos da circunferência menor de dentro dos raios
replica((216.0, 101.0), 5, ((209.2, 118.69), (210.7, 120.3), (213, 119.9)), (Path.MOVETO, Path.CURVE3, Path.CURVE3), 3, "white")
replica((216.0, 101.0), 5, ((219.2, 118.69), (219.7, 119.85), (223, 118.9)), (Path.MOVETO, Path.CURVE3, Path.CURVE3), 3, "white")
# Y QUE VAI SER REPETIDO AO LONGO DE 5 VEZES
replica((216.0, 101.0), 5, l, codes, 0.6)

reta((81.8, 154.8), (125.0, 137.2), 1, "gray", "-", 0.3)

reta((109.9, 85.8), (109.8, 80.75))

reta((42.0, 205.9), (42.0, 207.8))

ax.set_title("Lamborghini Sián FKP37", fontsize = 22)
ax.set_aspect(1)

lambo = plt.imread("Lamborghini Sian FKP 37 Right Side.png")

#plt.imshow(lambo, alpha=0.2, extent=[0, 1180, 0, 330])  # Para ver a plotagem com a imagem embaixo, remova este comentário

plt.xticks(np.linspace(0, 1180, 23))
plt.yticks(np.linspace(0, 330, 9))

#plt.rcParams['figure.figsize'] = (21, 12) # PARA ALTERAR O TAMANHO DA PLOTAGEM, MUDE ESTES VALORES

plt.show()

# %% [markdown]
# ![Lamborghini Sian FKP 37 Right Side.png](attachment:a605541f-7ef1-464f-94af-8f58282c0399.png)
